# %% [markdown]
# # In this notebook we are looking for miner the rules in our data

# %%
import pandas as pd
ready = pd.read_csv('source/ready_data.csv')
# Out:
# /home/visus/.pyenv/versions/3.7.0/lib/python3.7/site-packages/pandas/compat/__init__.py:117: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
ready
# Out:
#      sexo local_origem          tipo_instituicao        renda_familiar  \
# 0       M  Zona Urbana  Apenas em escola pública  Maior que R$ 1530,00
# 1       M   Zona Rural  Apenas em escola pública    R$ 511,00 a 765,00
# 2       F  Zona Urbana  Apenas em escola pública    R$ 511,00 a 765,00
# 3       M  Zona Urbana  Apenas em escola pública  R$ 1276,00 a 1530,00
# 4       F  Zona Urbana  Apenas em escola pública    R$ 511,00 a 765,00
# ...   ...          ...                       ...                   ...
# 1321    M  Zona Urbana  Apenas em escola pública   R$ 766,00 a 1275,00
# 1322    F  Zona Urbana  Apenas em escola pública    R$ 511,00 a 765,00
# 1323    M   Zona Rural  Apenas em escola pública   R$ 766,00 a 1275,00
# 1324    F  Zona Urbana  Apenas em escola pública  R$ 1276,00 a 1530,00
# 1325    M  Zona Urbana  Apenas em escola pública   R$ 766,00 a 1275,00
#
#      tipo_residencia grau_escolaridade                                 motivo  \
# ...
