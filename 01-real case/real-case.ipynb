# %%
import pandas as pd

data = pd.read_csv('static/real-case.csv', header = None)
data
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread               NaN
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken                NaN          NaN               NaN
# 7499       escalope          green tea          NaN               NaN
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# 0     green grapes  whole weat flour  yams  cottage cheese  energy drink
# 1              NaN               NaN   NaN             NaN           NaN
# 2              NaN               NaN   NaN             NaN           NaN
# 3              NaN               NaN   NaN             NaN           NaN
# 4        green tea               NaN   NaN             NaN           NaN
# ...            ...               ...   ...             ...           ...
# 7496           NaN               NaN   NaN             NaN           NaN
# 7497     magazines         green tea   NaN             NaN           NaN
# 7498           NaN               NaN   NaN             NaN           NaN
# 7499           NaN               NaN   NaN             NaN           NaN
# 7500           NaN               NaN   NaN             NaN           NaN
#
#                 9               10         11     12     13             14  \
# 0     tomato juice  low fat yogurt  green tea  honey  salad  mineral water
# 1              NaN             NaN        NaN    NaN    NaN            NaN
# 2              NaN             NaN        NaN    NaN    NaN            NaN
# 3              NaN             NaN        NaN    NaN    NaN            NaN
# 4              NaN             NaN        NaN    NaN    NaN            NaN
# ...            ...             ...        ...    ...    ...            ...
# 7496           NaN             NaN        NaN    NaN    NaN            NaN
# 7497           NaN             NaN        NaN    NaN    NaN            NaN
# 7498           NaN             NaN        NaN    NaN    NaN            NaN
# 7499           NaN             NaN        NaN    NaN    NaN            NaN
# 7500           NaN             NaN        NaN    NaN    NaN            NaN
#
#           15                 16               17       18         19
# 0     salmon  antioxydant juice  frozen smoothie  spinach  olive oil
# 1        NaN                NaN              NaN      NaN        NaN
# 2        NaN                NaN              NaN      NaN        NaN
# 3        NaN                NaN              NaN      NaN        NaN
# 4        NaN                NaN              NaN      NaN        NaN
# ...      ...                ...              ...      ...        ...
# 7496     NaN                NaN              NaN      NaN        NaN
# 7497     NaN                NaN              NaN      NaN        NaN
# 7498     NaN                NaN              NaN      NaN        NaN
# 7499     NaN                NaN              NaN      NaN        NaN
# 7500     NaN                NaN              NaN      NaN        NaN
#
# [7501 rows x 20 columns]

# %%
transactions = []
for i in range(0, len(data)):
    transactions.append([str(data.values[i, j]) for j in range(0, 4)])
len(transactions)
# Out:
# 7501

# %%
transactions[0]
# Out:
# ['shrimp', 'almonds', 'avocado', 'vegetables mix']

# %%
from apyori import apriori

rules = list(apriori(transactions, 
                     min_support = 0.01,
                     min_confidence = 0.01,
                     min_lift = 2,
                     min_lenght = 2))
rules
# Out:
# [RelationRecord(items=frozenset({'shrimp', 'frozen vegetables'}), support=0.01666444474070124, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frozen vegetables'}), items_add=frozenset({'shrimp'}), confidence=0.17556179775280897, lift=2.4614748503622805), OrderedStatistic(items_base=frozenset({'shrimp'}), items_add=frozenset({'frozen vegetables'}), confidence=0.23364485981308414, lift=2.461474850362281)]),
#  RelationRecord(items=frozenset({'tomatoes', 'frozen vegetables'}), support=0.01586455139314758, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frozen vegetables'}), items_add=frozenset({'tomatoes'}), confidence=0.16713483146067415, lift=2.4581928838951312), OrderedStatistic(items_base=frozenset({'tomatoes'}), items_add=frozenset({'frozen vegetables'}), confidence=0.23333333333333336, lift=2.4581928838951312)]),
#  RelationRecord(items=frozenset({'ground beef', 'herb & pepper'}), support=0.01386481802426343, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ground beef'}), items_add=frozenset({'herb & pepper'}), confidence=0.1471004243281471, lift=2.9741247517127527), OrderedStatistic(items_base=frozenset({'herb & pepper'}), items_add=frozenset({'ground beef'}), confidence=0.28032345013477084, lift=2.9741247517127527)]),
#  RelationRecord(items=frozenset({'ground beef', 'spaghetti'}), support=0.03159578722836955, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ground beef'}), items_add=frozenset({'spaghetti'}), confidence=0.33521923620933525, lift=2.076366218667402), OrderedStatistic(items_base=frozenset({'spaghetti'}), items_add=frozenset({'ground beef'}), confidence=0.1957060280759703, lift=2.076366218667402)]),
#  RelationRecord(items=frozenset({'tomatoes', 'shrimp'}), support=0.010931875749900012, ordered_statistics=[OrderedStatistic(items_base=frozenset({'shrimp'}), items_add=frozenset({'tomatoes'}), confidence=0.15327102803738318, lift=2.2542862378596302), OrderedStatistic(items_base=frozenset({'tomatoes'}), items_add=frozenset({'shrimp'}), confidence=0.1607843137254902, lift=2.2542862378596302)])]

# %%
rules = [list(elements) for elements in rules]
rules
# Out:
# [[frozenset({'frozen vegetables', 'shrimp'}),
#   0.01666444474070124,
#   [OrderedStatistic(items_base=frozenset({'frozen vegetables'}), items_add=frozenset({'shrimp'}), confidence=0.17556179775280897, lift=2.4614748503622805),
#    OrderedStatistic(items_base=frozenset({'shrimp'}), items_add=frozenset({'frozen vegetables'}), confidence=0.23364485981308414, lift=2.461474850362281)]],
#  [frozenset({'frozen vegetables', 'tomatoes'}),
#   0.01586455139314758,
#   [OrderedStatistic(items_base=frozenset({'frozen vegetables'}), items_add=frozenset({'tomatoes'}), confidence=0.16713483146067415, lift=2.4581928838951312),
#    OrderedStatistic(items_base=frozenset({'tomatoes'}), items_add=frozenset({'frozen vegetables'}), confidence=0.23333333333333336, lift=2.4581928838951312)]],
#  [frozenset({'ground beef', 'herb & pepper'}),
#   0.01386481802426343,
#   [OrderedStatistic(items_base=frozenset({'ground beef'}), items_add=frozenset({'herb & pepper'}), confidence=0.1471004243281471, lift=2.9741247517127527),
#    OrderedStatistic(items_base=frozenset({'herb & pepper'}), items_add=frozenset({'ground beef'}), confidence=0.28032345013477084, lift=2.9741247517127527)]],
#  [frozenset({'ground beef', 'spaghetti'}),
#   0.03159578722836955,
#   [OrderedStatistic(items_base=frozenset({'ground beef'}), items_add=frozenset({'spaghetti'}), confidence=0.33521923620933525, lift=2.076366218667402),
#    OrderedStatistic(items_base=frozenset({'spaghetti'}), items_add=frozenset({'ground beef'}), confidence=0.1957060280759703, lift=2.076366218667402)]],
#  [frozenset({'shrimp', 'tomatoes'}),
#   0.010931875749900012,
#   [OrderedStatistic(items_base=frozenset({'shrimp'}), items_add=frozenset({'tomatoes'}), confidence=0.15327102803738318, lift=2.2542862378596302),
#    OrderedStatistic(items_base=frozenset({'tomatoes'}), items_add=frozenset({'shrimp'}), confidence=0.1607843137254902, lift=2.2542862378596302)]]]

# %% [markdown]
# * __An observation before continue coding:__
# >    To return a considerable number of elements, I needed to set a much smaller number to my_support and to my_confidence
